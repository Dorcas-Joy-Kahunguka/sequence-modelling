# %%
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /home/joy/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import data_utils

# %%
prose_text=data_utils.load_prose_text("data/raw/prose-test-data.txt")

# %%
sentences=nltk.sent_tokenize(prose_text)
print(sentences)
# Out:
# ["Dr. Martinez wasn't expecting the well-documented report to arrive so early, but she'd already cleared her schedule for it.", 'Mr. Alvarez, her long-time colleague, dropped by around 9 a.m. to help review the data-driven findings before the noon meeting.', '"Isn\'t this a game-changer?"', "he asked, though they both knew the numbers weren't fully finalized yet.", 'Ms. Patel joined shortly after, bringing a much-needed second opinion on the fast-tracked timeline.', "By 11:45, they'd agreed the pre-approved budget wouldn't cover the additional testing — that's a problem!", "Still, Dr. Martinez wasn't worried; she'd handled tighter deadlines before."]
