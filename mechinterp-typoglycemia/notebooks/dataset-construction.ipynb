# %%
import os
print(os.getcwd())
# Out:
# /home/joy/Documents/sequence-modelling

# %%
os.chdir("/home/joy/Documents/sequence-modelling/mechinterp-typoglycemia")
print(os.getcwd())
# Out:
# /home/joy/Documents/sequence-modelling/mechinterp-typoglycemia

# %%
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /home/joy/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import data_utils

# %%
prose_text=data_utils.load_prose_text("data/raw/prose-test-data.txt")

# %%
sentences=nltk.sent_tokenize(prose_text)
print(sentences)
# Out:
# ["Dr. Martinez wasn't expecting the well-documented report to arrive so early, but she'd already cleared her schedule for it.", 'Mr. Alvarez, her long-time colleague, dropped by around tea-break to help review the data-driven findings before the noon meeting.', "He asked if the findings were not a game changer, though they both knew the numbers weren't fully finalized yet.", 'Ms. Patel joined shortly after, bringing a much-needed second opinion on the fast-tracked timeline.', "By quarter to noon, they'd agreed the pre-approved budget wouldn't cover the additional testing and that was a problem!", "Still, Dr. Martinez wasn't worried; she'd handled tighter deadlines before."]

# %%
cst_list = data_utils.build_cst_triplets(sentences)
print(cst_list)
# Out:
# [{'clean_context': "Dr. Martinez wasn't expecting the well-documented report to arrive so early, but she'd already cleared her schedule for", 'scrambled_context': "Dr. Metraniz wan'st etpxecnig the wtcoed-nlueemld rperot to avrrie so erlay, but seh'd aldarey ceelard her shcedlue for", 'target': 'it'}, {'clean_context': 'Mr. Alvarez, her long-time colleague, dropped by around tea-break to help review the data-driven findings before the noon', 'scrambled_context': 'Mr. Aarelvz, her lgnm-toie cuagolele, derpopd by anurod ter-baaek to hlep rveeiw the d-avteirdan fiinndgs bferoe the noon', 'target': 'meeting'}, {'clean_context': "He asked if the findings were not a game changer, though they both knew the numbers weren't fully finalized", 'scrambled_context': "He akesd if the fdngniis wree not a gmae cneaghr, tguohh tehy btoh kenw the neumrbs w'enret fluly faiilnzed", 'target': 'yet'}, {'clean_context': 'Ms. Patel joined shortly after, bringing a much-needed second opinion on the fast-trac
# ...

# %%
data_utils.generate_cst_json(cst_list)
